# %%
import tushare as ts
import pandas as pd
from pandas import DataFrame
from pandas import concat
from pandas import merge
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import time

# %% [markdown]
# # 1、读入数仓数据

# %%
# 读取year
def read_newyear():
    df = pd.read_csv('..\\JN_DataWarehouse\\stock_analysis\\TuShare\\new_year.csv' ,index_col=False)
    
    del df['Unnamed: 0']
    return df

# %%
# %%time
df_stock_all = read_newyear()
df_stock_all.head()
# Out:
# Wall time: 10.5 s

# %%
df_stock_all
# Out:
#            ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0        002007.SZ    20110104  48.51  48.69  47.42  48.13      48.39   -0.26
# 1        000088.SZ    20110104   6.15   6.18   6.09   6.17       6.13    0.04
# 2        000068.SZ    20110104   6.01   6.30   5.94   6.30       6.00    0.30
# 3        600167.SH    20110104   9.62   9.78   9.58   9.74       9.63    0.11
# 4        002418.SZ    20110104  22.05  22.64  22.01  22.58      22.00    0.58
# ...            ...         ...    ...    ...    ...    ...        ...     ...
# 6442705  300659.SZ    20200814  54.00  55.60  53.48  55.09      53.80    1.29
# 6442706  002852.SZ    20200814  21.34  21.58  20.40  20.99      21.34   -0.35
# 6442707  603960.SH    20200814  47.25  47.25  45.24  46.70      46.31    0.39
# 6442708  603896.SH    20200814  38.56  39.68  38.38  39.38      38.57    0.81
# 6442709  603138.SH    20200814  21.17  21.59  20.96  21.47      21.17    0.30
#
# ...

# %% [markdown]
# # 2、 tc_code & trade_date 过滤

# %%
# ts_code 过滤
df = df_stock_all.query("ts_code in ('601318.SH','601318.SH') | ts_code.str.contains('601318')")

# %%
# trade_date 过滤
df = df.query("trade_date > 20200101 & trade_date < 20201231")
df
# Out:
#            ts_code  trade_date   open   high    low  close  pre_close  change  \
# 5874274  601318.SH    20200102  85.90  86.79  85.88  86.12      85.46    0.66
# 5877295  601318.SH    20200103  86.81  86.88  85.90  86.20      86.12    0.08
# 5879817  601318.SH    20200106  85.92  86.87  85.50  85.60      86.20   -0.60
# 5884180  601318.SH    20200107  86.01  86.46  85.67  86.15      85.60    0.55
# 5888774  601318.SH    20200108  85.98  85.98  84.50  85.00      86.15   -1.15
# ...            ...         ...    ...    ...    ...    ...        ...     ...
# 6426284  601318.SH    20200810  76.02  77.69  75.82  77.01      76.33    0.68
# 6430187  601318.SH    20200811  77.45  78.68  76.51  76.77      77.01   -0.24
# 6434128  601318.SH    20200812  76.80  77.46  76.40  77.16      76.77    0.39
# 6436815  601318.SH    20200813  77.50  77.60  76.51  76.60      77.16   -0.56
# 6440990  601318.SH    20200814  76.47  78.49  76.34  78.19      76.60    1.59
#
# ...

# %% [markdown]
# # 3、数值分析

# %%
df.describe()
# Out:
#          trade_date        open        high         low       close  \
# count  1.500000e+02  150.000000  150.000000  150.000000  150.000000
# mean   2.020045e+07   76.544533   77.385467   75.813067   76.548933
# std    2.149297e+02    5.379589    5.409680    5.264247    5.288488
# min    2.020010e+07   66.000000   67.500000   66.000000   66.760000
# 25%    2.020030e+07   72.155000   72.985000   71.550000   72.207500
# 50%    2.020043e+07   76.085000   77.235000   75.725000   76.355000
# 75%    2.020062e+07   80.590000   81.427500   80.065000   80.685000
# max    2.020081e+07   88.300000   88.700000   87.350000   87.600000
#
#        pre_close      change     pct_chg           vol        amount
# count  150.00000  150.000000  150.000000  1.500000e+02  1.500000e+02
# mean    76.58880   -0.039867   -0.030423  7.167188e+05  5.559172e+06
# std      5.34322    1.435063    1.852712  3.802378e+05  3.161708e+06
# min     66.76000   -5.780000   -6.923000  2.684412e+05  1.901687e+06
# ...

# %%
print(np.pi)
print(np.sin(30*np.pi/180))
# Out:
# 3.141592653589793
# 0.49999999999999994

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-314b5dc91325> in <module>()
#       1 date_time = '01.01.2009 00:10:00'
# ----> 2 date_time_s = date_time.map(datetime.datetime.timestamp)
#       3 date_time_s
#
# AttributeError: 'str' object has no attribute 'map'
