# %%
import tushare as ts
import pandas as pd
from pandas import DataFrame
from pandas import concat
from pandas import merge
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import time

# %% [markdown]
# # 1、读入数仓数据

# %%
# 读取year
def read_newyear():
    df = pd.read_csv('..\\JN_DataWarehouse\\stock_analysis\\TuShare\\new_year.csv' ,index_col=False)
    
    del df['Unnamed: 0']
    return df

# %%
# %%time
df_stock_all = read_newyear()
df_stock_all.head()
# Out:
# Wall time: 9.4 s

# %%
df_stock_all
# Out:
#            ts_code  trade_date    open    high    low   close  pre_close  \
# 0        002007.SZ    20110104   48.51   48.69  47.42   48.13      48.39
# 1        000088.SZ    20110104    6.15    6.18   6.09    6.17       6.13
# 2        000068.SZ    20110104    6.01    6.30   5.94    6.30       6.00
# 3        600167.SH    20110104    9.62    9.78   9.58    9.74       9.63
# 4        002418.SZ    20110104   22.05   22.64  22.01   22.58      22.00
# ...            ...         ...     ...     ...    ...     ...        ...
# 6415362  688589.SH    20200805   71.58   73.29  68.18   70.83      66.65
# 6415363  688598.SH    20200805  101.50  106.58  99.02  105.00     100.20
# 6415364  688599.SH    20200805   17.24   17.24  16.87   17.15      17.18
# 6415365  688600.SH    20200805   28.31   28.64  27.85   28.01      28.30
# 6415366  688981.SH    20200805   87.00   87.00  82.58   83.00      81.08
#
#          change  pct_chg         vol        amount
# ...

# %% [markdown]
# # 2、 tc_code & trade_date 过滤

# %%
# ts_code 过滤
df = df_stock_all.query("ts_code in ('002007.SZ','002572.SZ') | ts_code.str.contains('601318')")

# %%
# ts_code 过滤
df1 = df.query("trade_date > 20110101 & trade_date < 20111231")
df1
# Out:
#           ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0       002007.SZ    20110104  48.51  48.69  47.42  48.13      48.39   -0.26
# 1877    601318.SH    20110104  56.85  57.60  56.50  56.91      56.16    0.75
# 3425    002007.SZ    20110105  47.98  47.98  46.49  46.70      48.13   -1.43
# 3498    601318.SH    20110105  56.59  56.80  54.80  54.86      56.91   -2.05
# 4463    002007.SZ    20110106  46.55  46.87  45.30  45.59      46.70   -1.11
# ...           ...         ...    ...    ...    ...    ...        ...     ...
# 191741  002007.SZ    20110527  34.95  35.49  34.00  34.08      35.11   -1.03
# 191875  601318.SH    20110527  47.72  48.41  47.70  47.97      47.72    0.25
# 192719  601318.SH    20110530  47.88  48.31  47.74  47.98      47.97    0.01
# 193520  002572.SZ    20110530  72.00  72.65  71.04  72.12      72.40   -0.28
# 194619  002007.SZ    20110530  34.20  34.30  32.64  32.67      34.08   -1.41
#
#         pct_chg        vol        amount
# ...
