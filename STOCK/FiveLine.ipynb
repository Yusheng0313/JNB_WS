# %%
#import talib                   #量化金融技术分析库
import os
import pandas as pd
import numpy as np
import cufflinks as cf
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.offline as pyoff
import plotly.io as pio
import plotly
import datetime
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 读取year
def read_newyear():
    df = pd.read_csv('../JN_DataWarehouse/stock_analysis/TuShare/new_year.csv' ,index_col=False)
    df['ts_code'] = df['ts_code'].apply(str)
    del df['Unnamed: 0']
    return df

# %%
df_stock_all = read_newyear()

# %%
# 插入py文件，调用里面的函数
from Stock_Interface import cli_fiveLine
from Stock_Interface import read_finance_year

# %%
stock_code = '601939'
today = datetime.date.today()                #datetime.date类型日期  today = datetime.date(2019,11,15)
today = today -  datetime.timedelta(365*0)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*0.5)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*1)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*1.5)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*2)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*2.5)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)

# %%
today = datetime.date.today()                #datetime.date类型日期  
today = today -  datetime.timedelta(365*3)
A3yday = today - datetime.timedelta(365*3.5)
startDate = A3yday.strftime('%Y%m%d')        #字符串型日期
endDate = today.strftime('%Y%m%d')

df_mode = cli_fiveLine.build_mode(df_stock_all, stock_code, startDate, endDate)
fig = cli_fiveLine.show_save_image(df_mode, stock_code)
