# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Mar  21 19:42:02 2020

@author: yihao.he
"""

from bs4 import BeautifulSoup  
import pandas as pd
from tqdm import tqdm
import math
import requests  
import lxml
import re
import time


# 房源面积-总价散点图
# 各行政区均价
# 均价最贵的10个地段
# 均价最贵的10个小区
# 户型分布
# 标题文本词云图


from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode
from jieba import posseg as psg
import collections


# 读入CSV 命名为data
data = pd.read_csv('.\JN_DataWarehouse\shenzhen_lianjiafangyuan\data.csv')
data.head()
# Out:
#    Unnamed: 0 area                         title community position    tax  \
# 0           0  罗湖区           此房楼龄新 京基物业 满二 业主诚心卖      凤凰印象       螺岭    NaN
# 1           1  罗湖区                 长丰苑 2室1厅 295万       长丰苑      春风路    NaN
# 2           2  罗湖区      高层厅出阳台户型，带花园泳池，视野无遮挡，满两年   阳光新干线家园      春风路    NaN
# 3           3  罗湖区  云景豪园厅出阳台2+1房 已改衣帽间，满五唯一  采光好      云景豪园      春风路  房本满五年
# 4           4  罗湖区        红本在手、地铁口物业、89年老旧小区坐等规划      宝岗花园       笋岗  房本满五年
#
#    total_price  unit_price hourseType  hourseSize direction fitment
# 0        304.0     73466.0       1室1厅       41.38         北      精装
# 1        295.0     43383.0       2室1厅       68.00        东南      精装
# 2        318.0     50799.0       2室1厅       62.60        东北      精装
# 3        355.0     48926.0       3室1厅       72.56        西北      精装
# 4        480.0     51315.0       3室2厅       93.54       南 北      简装

# %%
# 房源面积-总价散点图
# 💥最贵的一套房源是位于宝安-曦城的房源，总价8800W；

scatter = (Scatter(init_opts=opts.InitOpts(theme='dark'))
           .add_xaxis(data['hourseSize'])
           .add_yaxis("房价", data['total_price'])
           .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                           markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max", name="最大值"),]))
           .set_global_opts(
               legend_opts=opts.LegendOpts(is_show=False),
               title_opts=opts.TitleOpts(title="深圳二手房 总价-面积 散点图"),
               xaxis_opts=opts.AxisOpts(
                   name='面积',
                   # 设置坐标轴为数值类型
                   type_="value", 
                   # 不显示分割线
                   splitline_opts=opts.SplitLineOpts(is_show=False)),
               yaxis_opts=opts.AxisOpts(
                   name='总价',
                   name_location='middle',
                   # 设置坐标轴为数值类型
                   type_="value",
                   # 默认为False表示起始为0
                   is_scale=True,
                   splitline_opts=opts.SplitLineOpts(is_show=False),),
               visualmap_opts=opts.VisualMapOpts(is_show=True, type_='color', min_=100, max_=1000)
    ))

scatter.render_notebook()                      #直接在jupyter notebook 显示
# scatter.render('散点图.html')                #生成html文件
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9be4d28274914e2ca4c6cc3d3f016226" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9be4d28274914e2ca4c6cc3d3f016226 = echarts.init(
#                     document.getElementById('9be4d28274914e2ca4c6cc3d3f016226'), 'dark', {renderer: 'canvas'});
#                 var option_9be4d28274914e2ca4c6cc3d3f016226 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u623f\u4ef7",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     41.38,
#                     304.0
#                 ],
#                 [
#                     68.0,
#                     295.0
#                 ],
#                 [
#                     62.6,
#                     318.0
#                 ],
#                 [
#                     72.56,
#                     355.0
#                 ],
#                 [
#                     93.54,
#                     480.0
#                 ],
#                 [
#                     39.6,
#                     190.0
#                 ],
#                 [
#                     46.39,
#                     215.0
#                 ],
#                 [
#                     41.8,
#                     226.0
#                 ],
#                 [
#                     72.27,
#                     395.0
#                 ],
#                 [
#                     91.59,
#                     670.0
#                 ],
#                 [
#                     29.25,
#                     282.0
#                 ],
#                 [
#                     45.93,
#                     192.0
#                 ],
#                 [
#                     90.71,
#                     450.0
#                 ],
#                 [
#                     41.7,
#                     282.0
#                 ],
#                 [
#                     89.99,
#                     460.0
#                 ],
#                 [
#                     37.65,
#                     215.0
#                 ],
#                 [
#                     38.96,
#                     182.0
#                 ],
#                 [
#                     57.78,
#                     212.0
#                 ],
#                 [
#                     41.25,
#                     320.0
#                 ],
#                 [
#                     36.42,
#                     150.0
#                 ],
#                 [
#                     102.78,
#                     630.0
#                 ],
#                 [
#                     88.5,
#                     490.0
#                 ],
#                 [
#                     93.0,
#                     515.0
#                 ],
#                 [
#                     62.87,
#                     355.0
#                 ],
#                 [
#                     30.59,
#                     450.0
#                 ],
#                 [
#                     97.13,
#                     540.0
#                 ],
#                 [
#                     33.0,
#                     155.0
#                 ],
#                 [
#                     80.49,
#                     400.0
#                 ],
#                 [
#                     49.01,
#                     198.0
#                 ],
#                 [
#                     79.9,
#                     530.0
#                 ],
#                 [
#                     27.47,
#                     215.0
#                 ],
#                 [
#                     44.39,
#                     260.0
#                 ],
#                 [
#                     72.85,
#                     455.0
#                 ],
#                 [
#                     124.81,
#                     739.0
#                 ],
#                 [
#                     40.71,
#                     195.0
#                 ],
#                 [
#                     106.74,
#                     605.0
#                 ],
#                 [
#                     70.11,
#                     283.0
#                 ],
#                 [
#                     57.43,
#                     442.0
#                 ],
#                 [
#                     96.75,
#                     655.0
#                 ],
#                 [
#                     100.06,
#                     400.0
#                 ],
#                 [
#                     42.69,
#                     165.0
#                 ],
#                 [
#                     52.87,
#                     330.0
#                 ],
#                 [
#                     65.11,
#                     335.0
#                 ],
#                 [
#                     42.8,
#                     260.0
#                 ],
#                 [
#                     38.44,
#                     232.0
#                 ],
#                 [
#                     28.31,
#                     360.0
#                 ],
#                 [
#                     51.47,
#                     310.0
#                 ],
#                 [
#                     15.38,
#                     78.0
#                 ],
#                 [
#                     35.14,
#                     178.0
#                 ],
#                 [
#                     61.61,
#                     350.0
#                 ],
#                 [
#                     38.52,
#                     300.0
#                 ],
#                 [
#                     35.93,
#                     282.0
#                 ],
#                 [
#                     31.83,
#                     225.0
#                 ],
#                 [
#                     64.57,
#                     365.0
#                 ],
#                 [
#                     34.09,
#                     210.0
#                 ],
#                 [
#                     50.23,
#                     310.0
#                 ],
#                 [
#                     64.13,
#                     495.0
#                 ],
#                 [
#                     57.95,
#                     305.0
#                 ],
#                 [
#                     52.21,
#                     190.0
#                 ],
#                 [
#                     111.37,
#                     1250.0
#                 ],
#                 [
#                     83.84,
#                     380.0
#                 ],
#                 [
#                     69.14,
#                     380.0
#                 ],
#                 [
#                     95.35,
#                     499.0
#                 ],
#                 [
#                     65.93,
#                     405.0
#                 ],
#                 [
#                     62.93,
#                     420.0
#                 ],
#                 [
#                     41.11,
#                     505.0
#                 ],
#                 [
#                     70.74,
#                     460.0
#                 ],
#                 [
#                     60.55,
#                     280.0
#                 ],
#                 [
#                     35.27,
#                     450.0
#                 ],
#                 [
#                     57.95,
#                     295.0
#                 ],
#                 [
#                     50.63,
#                     362.0
#                 ],
#                 [
#                     70.62,
#                     499.0
#                 ],
#                 [
#                     43.86,
#                     272.0
#                 ],
#                 [
#                     62.43,
#                     450.0
#                 ],
#                 [
#                     77.22,
#                     426.0
#                 ],
#                 [
#                     22.33,
#                     112.0
#                 ],
#                 [
#                     52.63,
#                     210.0
#                 ],
#                 [
#                     52.0,
#                     255.0
#                 ],
#                 [

# %%
# 各行政区均价
# 最贵的是南山区，整体均价9.2W/平米；
# 最便宜的是坪山区，均价3.5W/平米；

temp = data.groupby(['area'])['unit_price'].mean().reset_index()
data_pair = [(row['area'], round(row['unit_price']/10000, 1)) for _, row in temp.iterrows()]


map_ = (Map(init_opts=opts.InitOpts(theme='dark'))
        .add("二手房均价", data_pair, '深圳', is_roam=False)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="深圳各行政区二手房均价"),
            legend_opts=opts.LegendOpts(is_show=False),
            tooltip_opts=opts.TooltipOpts(formatter='{b}:{c}万元'),
            visualmap_opts=opts.VisualMapOpts(min_=3, max_=10)
        )
       )

        
map_.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '深圳':'https://assets.pyecharts.org/assets/maps/guang3_dong1_shen1_zhen4'
#         }
#     });
# </script>
#
#         <div id="f272bbdf07a5459985ea7463a9aff605" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '深圳'], function(echarts) {
#                 var chart_f272bbdf07a5459985ea7463a9aff605 = echarts.init(
#                     document.getElementById('f272bbdf07a5459985ea7463a9aff605'), 'dark', {renderer: 'canvas'});
#                 var option_f272bbdf07a5459985ea7463a9aff605 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "\u4e8c\u624b\u623f\u5747\u4ef7",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u6df1\u5733",
#             "data": [
#                 {
#                     "name": "\u5357\u5c71\u533a",
#                     "value": 9.4
#                 },
#                 {
#                     "name": "\u576a\u5c71\u533a",
#                     "value": 3.6
#                 },
#                 {
#                     "name": "\u5b9d\u5b89\u533a",
#                     "value": 7.0
#                 },
#                 {
#                     "name": "\u76d0\u7530\u533a",
#                     "value": 5.0
#                 },
#                 {
#                     "name": "\u798f\u7530\u533a",
#                     "value": 7.8
#                 },
#                 {
#                     "name": "\u7f57\u6e56\u533a",
#                     "value": 5.8
#                 },
#                 {
#                     "name": "\u9f99\u534e\u533a",
#                     "value": 6.2
#                 },
#                 {
#                     "name": "\u9f99\u5c97\u533a",
#                     "value": 4.5
#                 }
#             ],
#             "roam": false,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e8c\u624b\u623f\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u4e8c\u624b\u623f\u5747\u4ef7": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}:{c}\u4e07\u5143",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6df1\u5733\u5404\u884c\u653f\u533a\u4e8c\u624b\u623f\u5747\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 3,
#         "max": 10,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_f272bbdf07a5459985ea7463a9aff605.setOption(option_f272bbdf07a5459985ea7463a9aff605);
#         });
#     </script>

# %%
# 均价最高的10个小区
# 该小区内在售房源至少3套才统计

temp = data.groupby(['community'])['unit_price'].agg(['mean', 'count']).reset_index()

# 该小区内至少3套在售房源才统计
data_pair = sorted([(row['community'], round(row['mean']/10000, 1)) if row['count']>=3 else (0, 0)
                    for _, row in temp.iterrows()], key=lambda x: x[1], reverse=True)[:10]

bar = (Bar(init_opts=opts.InitOpts(theme='dark'))
       .add_xaxis([x[0] for x in data_pair[::-1]])
       .add_yaxis('二手房均价', [x[1] for x in data_pair[::-1]])
       .set_series_opts(label_opts=opts.LabelOpts(is_show=True, 
                                                       position='insideRight',
                                                       font_style='italic'),
                            itemstyle_opts=opts.ItemStyleOpts(
                                color=JsCode("""new echarts.graphic.LinearGradient(1, 0, 0, 0, 
                                             [{
                                                 offset: 0,
                                                 color: 'rgb(0,206,209)'
                                             }, {
                                                 offset: 1,
                                                 color: 'rgb(218,165,32)'
                                             }])"""))
                            )
       .set_global_opts(
           title_opts=opts.TitleOpts(title="深圳二手房均价TOP 10小区"),
           legend_opts=opts.LegendOpts(is_show=False),
           tooltip_opts=opts.TooltipOpts(formatter='{b}:{c}万元'),
           xaxis_opts=opts.AxisOpts(min_=14),
       )
       .reversal_axis()
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d44e245852054cc4914d2e3d38b2d5a5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d44e245852054cc4914d2e3d38b2d5a5 = echarts.init(
#                     document.getElementById('d44e245852054cc4914d2e3d38b2d5a5'), 'dark', {renderer: 'canvas'});
#                 var option_d44e245852054cc4914d2e3d38b2d5a5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e8c\u624b\u623f\u5747\u4ef7",
#             "data": [
#                 15.6,
#                 15.8,
#                 15.9,
#                 15.9,
#                 16.1,
#                 16.1,
#                 16.1,
#                 16.1,
#                 16.1,
#                 16.8
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "insideRight",
#                 "margin": 8,
#                 "fontStyle": "italic"
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(1, 0, 0, 0,                                              [{                                                 offset: 0,                                                 color: 'rgb(0,206,209)'                                             }, {                                                 offset: 1,                                                 color: 'rgb(218,165,32)'                                             }])
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e8c\u624b\u623f\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u4e8c\u624b\u623f\u5747\u4ef7": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}:{c}\u4e07\u5143",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 14,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6ce2\u6258\u83f2\u8bfa\u7eaf\u6c34\u5cb8\u5341\u4e94\u671f",
#                 "\u6ee8\u6d77\u4e4b\u7a97",
#                 "\u90fd\u5e02\u7fe0\u6d77\u534e\u82d1",
#                 "\u4e2d\u65c5\u56fd\u9645\u516c\u99861\u671f",
#                 "\u7199\u56ed",
#                 "\u6851\u8fbe\u5c0f\u533a",
#                 "\u65b0\u5929\u9e45\u5821",
#                 "\u592a\u53e4\u57ce\u5357",
#                 "\u5357\u5929\u4e8c\u82b1\u56ed",
#                 "\u6df1\u5733\u6e7e1\u53f7"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6df1\u5733\u4e8c\u624b\u623f\u5747\u4ef7TOP 10\u5c0f\u533a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d44e245852054cc4914d2e3d38b2d5a5.setOption(option_d44e245852054cc4914d2e3d38b2d5a5);
#         });
#     </script>

# %%
# 均价最高的10个地段

temp = data.groupby(['position'])['unit_price'].mean().reset_index()
data_pair = sorted([(row['position'], round(row['unit_price']/10000, 1))
                    for _, row in temp.iterrows()], key=lambda x: x[1], reverse=True)[:10]

bar = (Bar(init_opts=opts.InitOpts(theme='dark'))
       .add_xaxis([x[0] for x in data_pair])
       .add_yaxis('二手房均价', [x[1] for x in data_pair])
       .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_style='italic'),
                            itemstyle_opts=opts.ItemStyleOpts(
                                color=JsCode("""new echarts.graphic.LinearGradient(0, 1, 0, 0, 
                                             [{
                                                 offset: 0,
                                                 color: 'rgb(0,206,209)'
                                             }, {
                                                 offset: 1,
                                                 color: 'rgb(218,165,32)'
                                             }])"""))
                            )
       .set_global_opts(
           title_opts=opts.TitleOpts(title="深圳二手房均价TOP 10地段"),
           legend_opts=opts.LegendOpts(is_show=False),
           tooltip_opts=opts.TooltipOpts(formatter='{b}:{c}万元'))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7af8a2f2925b456792214f2a13352164" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7af8a2f2925b456792214f2a13352164 = echarts.init(
#                     document.getElementById('7af8a2f2925b456792214f2a13352164'), 'dark', {renderer: 'canvas'});
#                 var option_7af8a2f2925b456792214f2a13352164 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e8c\u624b\u623f\u5747\u4ef7",
#             "data": [
#                 15.7,
#                 13.4,
#                 12.3,
#                 11.4,
#                 11.1,
#                 11.0,
#                 10.0,
#                 9.9,
#                 9.7,
#                 9.5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontStyle": "italic"
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(0, 1, 0, 0,                                              [{                                                 offset: 0,                                                 color: 'rgb(0,206,209)'                                             }, {                                                 offset: 1,                                                 color: 'rgb(218,165,32)'                                             }])
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e8c\u624b\u623f\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u4e8c\u624b\u623f\u5747\u4ef7": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}:{c}\u4e07\u5143",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6df1\u5733\u6e7e",
#                 "\u767e\u82b1",
#                 "\u9999\u871c\u6e56",
#                 "\u7ea2\u6811\u6e7e",
#                 "\u79d1\u6280\u56ed",
#                 "\u5b9d\u5b89\u4e2d\u5fc3",
#                 "\u86c7\u53e3",
#                 "\u534e\u5f3a\u5317",
#                 "\u524d\u6d77",
#                 "\u56ed\u5cad"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6df1\u5733\u4e8c\u624b\u623f\u5747\u4ef7TOP 10\u5730\u6bb5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7af8a2f2925b456792214f2a13352164.setOption(option_7af8a2f2925b456792214f2a13352164);
#         });
#     </script>

# %%
# 户型分布
# 三室依然是主力；
# 在深圳这种寸土寸金的地方，小户型占比也很多；

temp = data.groupby(['hourseType'])['area'].count().reset_index()
data_pair = sorted([(row['hourseType'], row['area'])
                    for _, row in temp.iterrows()], key=lambda x: x[1], reverse=True)[:10]

pie = (Pie(init_opts=opts.InitOpts(theme='dark'))
       .add('', data_pair,
            radius=["30%", "75%"],
            rosetype="radius")
       .set_global_opts(title_opts=opts.TitleOpts(title="深圳二手房 户型分布"),
                       legend_opts=opts.LegendOpts(is_show=False),)
       .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {d}%"))
      )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="444af4f36ae44374b75f502faa14c4a5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_444af4f36ae44374b75f502faa14c4a5 = echarts.init(
#                     document.getElementById('444af4f36ae44374b75f502faa14c4a5'), 'dark', {renderer: 'canvas'});
#                 var option_444af4f36ae44374b75f502faa14c4a5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "3\u5ba42\u5385",
#                     "value": 4456
#                 },
#                 {
#                     "name": "2\u5ba41\u5385",
#                     "value": 3211
#                 },
#                 {
#                     "name": "3\u5ba41\u5385",
#                     "value": 2622
#                 },
#                 {
#                     "name": "4\u5ba42\u5385",
#                     "value": 2559
#                 },
#                 {
#                     "name": "1\u5ba41\u5385",
#                     "value": 1827
#                 },
#                 {
#                     "name": "2\u5ba42\u5385",
#                     "value": 1526
#                 },
#                 {
#                     "name": "5\u5ba42\u5385",
#                     "value": 968
#                 },
#                 {
#                     "name": "1\u5ba40\u5385",
#                     "value": 890
#                 },
#                 {
#                     "name": "4\u5ba41\u5385",
#                     "value": 770
#                 },
#                 {
#                     "name": "5\u5ba41\u5385",
#                     "value": 218
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "3\u5ba42\u5385",
#                 "2\u5ba41\u5385",
#                 "3\u5ba41\u5385",
#                 "4\u5ba42\u5385",
#                 "1\u5ba41\u5385",
#                 "2\u5ba42\u5385",
#                 "5\u5ba42\u5385",
#                 "1\u5ba40\u5385",
#                 "4\u5ba41\u5385",
#                 "5\u5ba41\u5385"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6df1\u5733\u4e8c\u624b\u623f \u6237\u578b\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_444af4f36ae44374b75f502faa14c4a5.setOption(option_444af4f36ae44374b75f502faa14c4a5);
#         });
#     </script>

# %%
# 词云图
# 来看看房源标题中出现最多的词语

word_list = []
stop_words = ['花园','业主','出售']
string =  str(''.join([i for i in data['title'] if isinstance(i, str)]))


words = psg.cut(string)
for x in words:
    if len(x.word)==1:
        pass
    elif x.flag in ('m', 'x'):
        pass
    elif x.word in stop_words:
        pass
    else:
        word_list.append(x.word)


data_pair = collections.Counter(word_list).most_common(100)


wc = (WordCloud()
      .add("", data_pair, word_size_range=[20, 100], shape='triangle')
      .set_global_opts(title_opts=opts.TitleOpts(title="房源描述词云图"))
    )

wc.render_notebook()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\pc-01\AppData\Local\Temp\jieba.cache
# Loading model cost 2.544 seconds.
# Prefix dict has been built successfully.
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="023c4c932eaf4038994052749f0dcfc9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_023c4c932eaf4038994052749f0dcfc9 = echarts.init(
#                     document.getElementById('023c4c932eaf4038994052749f0dcfc9'), 'white', {renderer: 'canvas'});
#                 var option_023c4c932eaf4038994052749f0dcfc9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "triangle",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6237\u578b",
#                     "value": 3203,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,42,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bda\u5fc3",
#                     "value": 3025,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,60,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u623f",
#                     "value": 2610,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,8,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u6b63",
#                     "value": 2417,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,97,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u697c\u5c42",
#                     "value": 2414,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,59,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91c7\u5149",
#                     "value": 2398,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,50,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 2137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,21,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u552f\u4e00",
#                     "value": 2133,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,10,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u672c",
#                     "value": 2087,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,26,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b89\u9759",
#                     "value": 1967,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,31,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u94c1\u53e3",
#                     "value": 1873,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,138,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5\u4fee",
#                     "value": 1660,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,120,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u5e74",
#                     "value": 1641,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,58,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89c6\u91ce",
#                     "value": 1516,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,107,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": 1494,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,113,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5728\u624b",
#                     "value": 1467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,156,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9633\u53f0",
#                     "value": 1412,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,70,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u770b\u623f",
#                     "value": 1321,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,116,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u533a",
#                     "value": 1266,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,52,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u88c5\u4fee",
#                     "value": 1263,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,60,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7269\u4e1a",
#                     "value": 1242,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,96,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u671d\u5357",
#                     "value": 1124,
#                     "textStyle": {
#                         "normal": {
